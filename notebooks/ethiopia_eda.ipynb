# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("../data/ethiopia.csv")
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  11.73    22.75     3.44      19.31          0.0  41.79  2.73
# 1  2015    2  12.30    24.01     4.09      19.92          0.0  33.29  2.39
# 2  2015    3  12.49    24.17     3.97      20.20          0.0  33.83  1.77
# 3  2015    4  14.08    23.78     6.90      16.88          0.0  38.84  0.87
# 4  2015    5  14.06    23.15     7.32      15.83          0.0  47.07  1.34
#
#    WS2M_MAX     PS  QV2M
# 0      5.07  77.13  4.00
# 1      4.19  77.14  3.35
# 2      2.76  77.11  3.43
# 3      1.28  77.07  4.60
# 4      2.14  77.01  5.58

# %%
df["Country"] = "Ethiopia"

# %%
df["Date"] = pd.to_datetime(df["YEAR"]*1000 + df["DOY"], format="%Y%j")

# %%
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  11.73    22.75     3.44      19.31          0.0  41.79  2.73
# 1  2015    2  12.30    24.01     4.09      19.92          0.0  33.29  2.39
# 2  2015    3  12.49    24.17     3.97      20.20          0.0  33.83  1.77
# 3  2015    4  14.08    23.78     6.90      16.88          0.0  38.84  0.87
# 4  2015    5  14.06    23.15     7.32      15.83          0.0  47.07  1.34
#
#    WS2M_MAX     PS  QV2M   Country       Date
# 0      5.07  77.13  4.00  Ethiopia 2015-01-01
# 1      4.19  77.14  3.35  Ethiopia 2015-01-02
# 2      2.76  77.11  3.43  Ethiopia 2015-01-03
# 3      1.28  77.07  4.60  Ethiopia 2015-01-04
# 4      2.14  77.01  5.58  Ethiopia 2015-01-05

# %%
df["Month"] = df["Date"].dt.month

# %%
df.replace(-999, np.nan, inplace=True)
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  11.73    22.75     3.44      19.31         0.00  41.79  2.73
# 1     2015    2  12.30    24.01     4.09      19.92         0.00  33.29  2.39
# 2     2015    3  12.49    24.17     3.97      20.20         0.00  33.83  1.77
# 3     2015    4  14.08    23.78     6.90      16.88         0.00  38.84  0.87
# 4     2015    5  14.06    23.15     7.32      15.83         0.00  47.07  1.34
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  16.99    24.29    11.80      12.49         5.27  73.87  1.79
# 4104  2026   87  15.29    19.58    12.08       7.50         6.46  80.85  1.13
# 4105  2026   88  16.28    22.34    11.69      10.65         9.53  77.96  1.30
# 4106  2026   89  17.66    25.31    11.08      14.23         0.85  68.88  2.02
# 4107  2026   90  18.25    26.36    12.14      14.22         0.40  63.95  2.18
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#               YEAR          DOY         T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.00000  4108.000000  4108.000000
# mean   2020.131451   180.121227    16.06850    23.199175    10.227544
# min    2015.000000     1.000000    10.03000    15.650000     1.170000
# 25%    2017.000000    86.000000    14.82000    21.110000     8.417500
# 50%    2020.000000   179.000000    16.04000    22.740000    10.990000
# 75%    2023.000000   272.000000    17.36000    25.170000    12.220000
# max    2026.000000   366.000000    21.53000    30.930000    15.680000
# std       3.248907   106.294767     1.89805     2.751471     2.607256
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     12.971631     3.633795    68.408588     1.979998     3.575246
# min       3.560000     0.000000    14.420000     0.460000     0.790000
# ...

# %% [markdown]
# The mean daily temperature (T2M) is approximately 16.07°C, indicating a generally mild climate across the dataset period.
# Maximum temperatures reach up to 30.93°C, while minimum temperatures drop as low as 1.17°C, showing strong seasonal variation.
# The relatively low standard deviation (~1.9°C for T2M) suggests temperature is fairly stable over time with gradual seasonal shifts rather than extreme fluctuations.

# %%
df.isna().sum()
# Out:
# YEAR           0
# DOY            0
# T2M            0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# PRECTOTCORR    0
# RH2M           0
# WS2M           0
# WS2M_MAX       0
# PS             0
# QV2M           0
# Country        0
# Date           0
# Month          0
# dtype: int64

# %%
(df.isna().sum()/len(df))*100
# Out:
# YEAR           0.0
# DOY            0.0
# T2M            0.0
# T2M_MAX        0.0
# T2M_MIN        0.0
# T2M_RANGE      0.0
# PRECTOTCORR    0.0
# RH2M           0.0
# WS2M           0.0
# WS2M_MAX       0.0
# PS             0.0
# QV2M           0.0
# Country        0.0
# Date           0.0
# Month          0.0
# dtype: float64

# %%
cols = ["T2M","T2M_MAX","T2M_MIN","PRECTOTCORR","RH2M","WS2M","WS2M_MAX"]

z_scores = np.abs(stats.zscore(df[cols], nan_policy='omit'))

outliers = (z_scores > 3).sum()
outliers
# Out:
# np.int64(137)

# %%
df.fillna(method="ffill", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.fillna(method="ffill", inplace=True)
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'method'

# %%
df = df.ffill()

# %%
df.to_csv("../data/ethiopia_clean.csv", index=False)

# %%
monthly_temp = df.groupby("Month")["T2M"].mean()

monthly_temp.plot(figsize=(10,5))
plt.title("Monthly Average Temperature - Ethiopia")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
monthly_prec = df.groupby("Month")["PRECTOTCORR"].sum()

monthly_prec.plot(kind="bar", figsize=(10,5))
plt.title("Monthly Total Precipitation - Ethiopia")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm")
plt.show()

# %%
sns.scatterplot(x="T2M", y="RH2M", data=df)
plt.show()

# %%
plt.hist(df["PRECTOTCORR"].dropna(), bins=30)
plt.title("Precipitation Distribution")
plt.show()

# %%
plt.scatter(df["T2M"], df["RH2M"], s=df["PRECTOTCORR"]*10, alpha=0.5)
plt.xlabel("Temperature")
plt.ylabel("Humidity")
plt.show()
